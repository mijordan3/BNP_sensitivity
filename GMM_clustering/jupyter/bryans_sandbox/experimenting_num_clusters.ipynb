# %%
git_repo = '../../../../'

import sys
import os

sys.path.insert(0, os.path.join(git_repo, 'BNP_sensitivity/GMM_clustering/'))
sys.path.insert(0, '../../../../LinearResponseVariationalBayes.py/')

# Linear response libraries
import LinearResponseVariationalBayes as vb
import LinearResponseVariationalBayes.SparseObjectives as obj_lib
import LinearResponseVariationalBayes.OptimizationUtils as opt_lib

# Local libraries
import gmm_clustering_lib as gmm_utils
import modeling_lib 
import functional_sensitivity_lib as fun_sens_lib 
import utils_lib

import matplotlib.pyplot as plt
# %matplotlib inline

from copy import deepcopy

import autograd
from autograd import numpy as np
from autograd import scipy as sp

# import numpy as np
# import scipy as sp

np.random.seed(453453)

import json

# %% [markdown]
# # Set up model

# %%
# Load results from previous fit.
json_input_file = os.path.join(
    git_repo, 'BNP_sensitivity/GMM_clustering/iris_fits/bnp_full_data_fit_alpha8.0_iris.json')

with open(json_input_file, 'r') as fp:
    fit_dict = json.load(fp)
    model = gmm_utils.get_model_from_checkpoint(fit_dict)
    model_ = gmm_utils.get_model_from_checkpoint(fit_dict)
    best_param = model.global_vb_params.get_free()
    kl_hessian = gmm_utils.get_kl_hessian_from_checkpoint(fit_dict)

# %%
print(model.prior_params)
# Out:
# prior_params:
# 	alpha: [8.]
# 	prior_centroid_mean: [0.]
# 	prior_centroid_info: [0.1]
# 	prior_gamma_df: [8.]
# 	prior_gamma_inv_scale:
# [[0.62 0.   0.   0.  ]
#  [0.   0.62 0.   0.  ]
#  [0.   0.   0.62 0.  ]
#  [0.   0.   0.   0.62]]

# %% [markdown]
# # Define a perturbation

# %%
# Define a perturbation in the logit v space.

phi_center = -2
#phi_log_rescale = stick_sens.get_log_p0_logit_stick(phi_center)
phi_log_rescale = -np.log(0.5)
print(phi_log_rescale)
def log_phi(logit_v):
    return(-0.5 * (logit_v - phi_center) ** 2 - phi_log_rescale)

def phi(logit_v):
    return np.exp(log_phi(logit_v))
# Out:
# 0.6931471805599453

# %% [markdown]
# This perturbation class is based on the contamination model
#
# $$
# p_c(\theta | \epsilon, \phi) =  p_0(\theta) \left(1 + \epsilon \phi(\theta) \right)
# $$
#
# This corresponds to Gustafson's linear model.  One big problem is that you must take $\epsilon \rightarrow \infty$.  Another is that, even if you set it up as a normalized mixture, the scale of the perturbation determines the derivative.  I think it is worth experimenting with the model
#
# \begin{align}
# p_c(\theta | \epsilon, \phi) &= p_0(\theta)^{1 - \epsilon} p_1(\theta)^\epsilon \\
# & = p_0(\theta) \left(\frac{p_1(\theta)}{p_0(\theta)}\right)^\epsilon \\
# & =: p_0(\theta) (C_1 \phi(\theta)) ^ \epsilon
# \end{align}
#
# because, among other things, it is invariant to the scaling $C_1$.

# %%
prior_perturbation = fun_sens_lib.PriorPerturbation(model, log_phi)
print(
    prior_perturbation.log_norm_p0,
    prior_perturbation.log_norm_pc,
    prior_perturbation.log_norm_p0_logit,
    prior_perturbation.log_norm_pc_logit)
# Out:
# 3.4618220034785896 -3.6937667578411086 -2.2246409632880852 -1.0222582344004703

# %%
prior_perturbation.set_epsilon(1.0)

logit_v_grid = np.linspace(-4, 4, 200)
v_grid = np.exp(logit_v_grid) / (1 + np.exp(logit_v_grid))

print('phi max: ', np.max(phi(logit_v_grid)))

plt.figure(1, figsize=(18, 5))

#plt.plot(v_grid, phi(logit_v_grid))
plt.subplot(141)
plt.plot(logit_v_grid, prior_perturbation.get_log_p0_logit(logit_v_grid))
plt.plot(logit_v_grid, prior_perturbation.get_log_pc_logit(logit_v_grid))
plt.title('Log priors in logit space')

plt.subplot(142)
plt.plot(logit_v_grid, np.exp(prior_perturbation.log_phi(logit_v_grid)))
plt.title('phi in logit space')

plt.subplot(143)
plt.plot(v_grid, np.exp(prior_perturbation.get_log_p0(v_grid)))
plt.plot(v_grid, np.exp(prior_perturbation.get_log_pc(v_grid)))
plt.title('Priors in stick space')

plt.subplot(144)
plt.plot(logit_v_grid, np.exp(prior_perturbation.get_log_p0_logit(logit_v_grid)))
plt.plot(logit_v_grid, np.exp(prior_perturbation.get_log_pc_logit(logit_v_grid)))
plt.title('Priors in logit space')
# Out:
# phi max:  0.49997474875006853

# %% [markdown]
# # Experimenting w GH points

# %%
# Choose the number of GH points.
import LinearResponseVariationalBayes.ExponentialFamilies as ef
model.global_vb_params.set_free(best_param)
vb_params = deepcopy(model.vb_params)

prior_perturbation.set_epsilon(1.0)

expected_perturbations_list = []
gh_deg_list = np.arange(3, 100, 1)
for gh_deg in gh_deg_list:
    gmm_utils.set_gauss_hermite_points(
        prior_perturbation.model.vb_params, gh_deg=gh_deg)
    expected_perturbations_list.append(
        prior_perturbation.get_e_log_perturbation(sum_vector=False))

print(expected_perturbations_list[0])
expected_perturbations_list = np.array(expected_perturbations_list)
#print(expected_perturbations_list.shape)
diffs = (expected_perturbations_list[1:, :] - \
         expected_perturbations_list[:-1, :]) / \
        np.abs(expected_perturbations_list[1:, :] + 1e-6)
#print(np.max(diffs, axis=1))
max_diffs = np.max(np.abs(diffs), axis=1)
print(max_diffs)
gh_deg_threshold = np.argmax(max_diffs < 1e-5)
gh_deg = max(20, gh_deg_threshold)
print(gh_deg, gh_deg_threshold, len(max_diffs))
# Out:
# [2.08720797 3.08838927 1.74574207 1.80912471 2.19652354 2.24073044
#  2.27924812 2.31409619 2.34613173 2.37574582 2.40311219]
# [3.96378791e-16 2.12767009e-16 6.35960150e-16 6.06534372e-16
#  5.84520409e-16 3.89680272e-16 2.02178124e-16 5.67856888e-16
#  7.57142517e-16 3.83812064e-16 5.67856888e-16 5.67856888e-16
#  2.45471726e-16 3.89680272e-16 5.75172399e-16 3.96378791e-16
#  4.25534018e-16 5.54392375e-16 5.54392375e-16 5.84520409e-16
#  5.84520409e-16 2.12767009e-16 3.96378791e-16 3.89680272e-16
#  4.04356248e-16 4.04356248e-16 2.12767009e-16 4.04356248e-16
#  2.12767009e-16 1.98189396e-16 3.96378791e-16 4.25534018e-16
#  1.91906032e-16 1.94840136e-16 3.78571259e-16 2.54384060e-16
#  1.94840136e-16 1.91906032e-16 2.12767009e-16 3.73852303e-16
#  3.69594917e-16 2.45471726e-16 4.25534018e-16 1.91906032e-16
#  3.96378791e-16 4.25534018e-16 4.25534018e-16 2.54384060e-16
#  2.54384060e-16 4.25534018e-16 3.89680272e-16 5.84520409e-16
#  2.02178124e-16 4.25534018e-16 2.54384060e-16 2.87586200e-16
#  4.31379299e-16 4.31379299e-16 3.78571259e-16 4.04356248e-16
#  4.04356248e-16 2.12767009e-16 4.25534018e-16 6.06534372e-16
#  1.98189396e-16 5.94568187e-16 5.75172399e-16 3.73852303e-16
#  2.02178124e-16 4.04356248e-16 2.45471726e-16 3.96378791e-16
#  2.87586200e-16 2.02178124e-16 3.83812064e-16 2.12767009e-16
#  3.89680272e-16 1.94840136e-16 5.08768120e-16 4.04356248e-16
#  4.25534018e-16 2.12767009e-16 2.45471726e-16 3.78571259e-16
#  3.78571259e-16 3.96378791e-16 6.38301027e-16 4.25534018e-16
#  3.83812064e-16 4.25534018e-16 4.25534018e-16 4.25534018e-16
#  3.69594917e-16 3.78571259e-16 2.12767009e-16 1.84797458e-16]
# 20 0 96

# %%
# First fit with no perturbation but the increased number of gh points.

model.objective.logger.print_every = 10
gmm_utils.set_gauss_hermite_points(model.vb_params, gh_deg=gh_deg)

best_param_0, converged, x_conv, f_conv, grad_conv, obj_opt, opt_results = \
    opt_lib.repeatedly_optimize(
        objective=prior_perturbation.objective,
        optimization_fun=lambda x: gmm_utils.precondition_and_optimize(model.objective, x),
        init_x=best_param,
        initial_optimization_fun=None,
        max_iter=100,
        gtol=1e-8, ftol=1e-8, xtol=1e-8, disp=False,
        keep_intermediate_optimizations=True)

kl_hessian_0 = model.objective.fun_free_hessian(best_param_0)
    
print('Done. ')
# Out:
# Iter: 0	 RMSE: 11.252659819113031	 Objective: -305.35833030090663
# Iter: 1	 RMSE: 11.252659791490329	 Objective: -305.35833030091084
# Optimization terminated successfully.
#          Current function value: -305.358330
#          Iterations: 1
#          Function evaluations: 2
#          Gradient evaluations: 2
#          Hessian evaluations: 0
# Iter: 2	 RMSE: 11.252659791490329	 Objective: -305.358330300911
# Iter: 3	 RMSE: 11.252659791498784	 Objective: -305.35833030091027
# Warning: A bad approximation caused failure to predict improvement.
#          Current function value: -305.358330
#          Iterations: 0
#          Function evaluations: 2
#          Gradient evaluations: 1
#          Hessian evaluations: 0
# Done.

# %% [markdown]
# # Get sensitivity class

# %%
# This expects the hyperparameter to be at its optimal value.
e_num_clusters_class = gmm_utils.ExpectedNumClusters(model)
e_num_clusters_class.set_e_num_clusters_from_free_param(best_param_0)

prior_perturbation.set_epsilon(0.0)
epsilon_sensitivity = \
    obj_lib.ParametricSensitivity(
        objective_fun=model.set_z_get_kl,
        input_par=e_num_clusters_class.model.global_vb_params,
        output_par=e_num_clusters_class.e_num_clusters,
        hyper_par=prior_perturbation.epsilon_param,
        input_to_output_converter=e_num_clusters_class.set_e_num_clusters,
        optimal_input_par=best_param_0,
        objective_hessian=kl_hessian_0,
        hyper_par_objective_fun=prior_perturbation.get_e_log_perturbation)

# %%
prior_perturbation.get_e_log_perturbation()
np.linalg.norm(epsilon_sensitivity.get_dinput_dhyper())
# Out:
# 14.025327992564304

# %% [markdown]
# # Fit with perturbation

# %%
epsilon = 0.2 # prior_perturbation.epsilon_param.get()
print('Epsilon: ', epsilon)

best_param_phi_pred = \
    epsilon_sensitivity.predict_input_par_from_hyperparameters(epsilon)
output_phi_pred = epsilon_sensitivity.predict_output_par_from_hyperparameters(
    epsilon, linear=True)

print('Predicted differences: ', np.linalg.norm(best_param_phi_pred - best_param_0))
# Out:
# Epsilon:  0.2
# Predicted differences:  2.805065598512861

# %%
# Then fit with the perturbation.
prior_perturbation.set_epsilon(epsilon)
print(prior_perturbation.epsilon_param)
best_param_phi, converged, x_conv, f_conv, grad_conv, obj_opt, opt_results = \
    opt_lib.repeatedly_optimize(
        objective=prior_perturbation.objective,
        optimization_fun=
            lambda x: gmm_utils.precondition_and_optimize(
                prior_perturbation.objective, x),
        init_x=best_param_phi_pred,
        initial_optimization_fun=None,
        keep_intermediate_optimizations=True)
print('Done. Converged: ', converged)

print('This is nonzero if phi did anything:', np.linalg.norm(best_param_phi - best_param_0))
# Out:
# epsilon: 0.2
# Iter  0  value:  -300.52216735307775
# Iter  1  value:  -301.00570386834187
# Iter  2  value:  -301.05913270069806
# Iter  3  value:  -301.06144515136714
# Iter  4  value:  -301.06181810522514
# Iter  5  value:  -301.06183808893934
# Iter  6  value:  -301.06183813426367
# Iter  7  value:  -301.06183813426594
# Optimization terminated successfully.
#          Current function value: -301.061838
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 8
#          Hessian evaluations: 0
# Iter  8  value:  -301.0618381342662
# Iter  9  value:  -301.06183813426514
# Warning: A bad approximation caused failure to predict improvement.
#          Current function value: -301.061838
#          Iterations: 0
#          Function evaluations: 2
#          Gradient evaluations: 1
#          Hessian evaluations: 0
# Done. Converged:  True
# This is nonzero if phi did anything: 1.7110019306262738

# %%
# Get e_num_clusters before and after perturbation
output_phi = e_num_clusters_class.set_and_get_e_num_clusters_from_free_param(best_param_phi)
output_0 = e_num_clusters_class.set_and_get_e_num_clusters_from_free_param(best_param_0)

# %% [markdown]
# # Check results

# %%
print('Epsilon:', epsilon)

plt.figure()
plt.subplot(1, 2, 1)
plt.plot(best_param_phi - best_param_0, best_param_phi_pred - best_param_0, 'k.')
plt.plot(best_param_phi - best_param_0, best_param_phi - best_param_0, 'r')

# plt.subplot(1, 2, 2)
# plt.plot(output_phi - output_0, output_phi_pred - output_0, 'k.')
# plt.plot(output_phi - output_0, output_phi - output_0, 'r')
# Out:
# Epsilon: 0.2

# %%
output_0
# Out:
# array([8.51880598])

# %%
output_phi
# Out:
# array([9.46613235])

# %%
output_phi_pred
# Out:
# array([9.97754169])

# %% [markdown]
# # Fit with range of perturbations

# %%
# epsilon_vec = np.linspace(0.1, 1.0, 4)
epsilon_vec = [0.01, 0.05, 0.1, 0.15, 0.2, 0.3, 0.4, 0.6, 0.8, 1.0]
print(epsilon_vec)
# Out:
# [0.01, 0.05, 0.1, 0.15, 0.2, 0.3, 0.4, 0.6, 0.8, 1.0]

# %%
best_param_phi_array = []
best_param_phi_pred_array = []

output_phi_array = []
output_phi_pred_array = []

# %%
for i in range(len(epsilon_vec)): 
    epsilon = epsilon_vec[i]
    print('Epsilon: ', epsilon)
    
    # get linear predictions
    best_param_phi_pred = \
        epsilon_sensitivity.predict_input_par_from_hyperparameters(epsilon)
    output_phi_pred = epsilon_sensitivity.predict_output_par_from_hyperparameters(
        epsilon, linear=True)

    print('Predicted differences: ', np.linalg.norm(best_param_phi_pred - best_param_0))
    
    # Then fit with the perturbation.
    prior_perturbation.set_epsilon(epsilon_vec[i])
    print(prior_perturbation.epsilon_param)
    best_param_phi, converged, x_conv, f_conv, grad_conv, obj_opt, opt_results = \
        opt_lib.repeatedly_optimize(
            objective=prior_perturbation.objective,
            optimization_fun=
                lambda x: gmm_utils.precondition_and_optimize(
                    prior_perturbation.objective, x),
            init_x=best_param_phi_pred,
            initial_optimization_fun=None,
            keep_intermediate_optimizations=True)

    output_phi = e_num_clusters_class.set_and_get_e_num_clusters_from_free_param(best_param_phi)

    print('Done. Converged: ', converged)

    print('This is nonzero if phi did anything:', np.linalg.norm(best_param_phi - best_param_0))
    
    # save results: 
    best_param_phi_array.append(best_param_phi)
    best_param_phi_pred_array.append(best_param_phi_pred)
    
    output_phi_array.append(output_phi)
    output_phi_pred_array.append(output_phi_pred)
# Out:
# Epsilon:  0.01
# Predicted differences:  0.14025327992564307
# epsilon: 0.01
# /home/runjing_liu/anaconda3/lib/python3.6/site-packages/scipy/integrate/quadrature.py:199: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.485226e-06
#   AccuracyWarning)
# Iter  144  value:  -305.1120099878353
# Iter  145  value:  -305.1120147705372
# Iter  146  value:  -305.1120147734505
# Optimization terminated successfully.
#          Current function value: -305.112015
#          Iterations: 2
#          Function evaluations: 3
#          Gradient evaluations: 3
#          Hessian evaluations: 0
# Iter  147  value:  -305.11201477345105
# Iter  148  value:  -305.11201477345026
# Optimization terminated successfully.
#          Current function value: -305.112015
#          Iterations: 1
#          Function evaluations: 2
#          Gradient evaluations: 1
#          Hessian evaluations: 0
# Done. Converged:  True
# This is nonzero if phi did anything: 0.13501698351362287
# Epsilon:  0.05
# Predicted differences:  0.7012663996282152
# epsilon: 0.05
# /home/runjing_liu/anaconda3/lib/python3.6/site-packages/scipy/integrate/quadrature.py:199: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.092171e-06
#   AccuracyWarning)
# Iter  149  value:  -304.16841114817737
# Iter  150  value:  -304.1709782110002
# Iter  151  value:  -304.1711161834494
# Iter  152  value:  -304.17111747023074
# Iter  153  value:  -304.1711174732656
# Optimization terminated successfully.
#          Current function value: -304.171117
#          Iterations: 4
#          Function evaluations: 5
#          Gradient evaluations: 5
#          Hessian evaluations: 0
# Iter  154  value:  -304.1711174732657
# Iter  155  value:  -304.17111747326805
# Optimization terminated successfully.
#          Current function value: -304.171117
#          Iterations: 1
#          Function evaluations: 2
#          Gradient evaluations: 2
#          Hessian evaluations: 0
# Done. Converged:  True
# This is nonzero if phi did anything: 0.5928587529639067
# Epsilon:  0.1
# Predicted differences:  1.4025327992564305
# epsilon: 0.1
# /home/runjing_liu/anaconda3/lib/python3.6/site-packages/scipy/integrate/quadrature.py:199: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.557954e-08
#   AccuracyWarning)
# Iter  156  value:  -303.0342106127615
# Iter  157  value:  -303.06779137131923
# Iter  158  value:  -303.0730950862958
# Iter  159  value:  -303.0735886895916
# Iter  160  value:  -303.0736716449374
# Iter  161  value:  -303.0736727028795
# Iter  162  value:  -303.0736727031955
# Optimization terminated successfully.
#          Current function value: -303.073673
#          Iterations: 6
#          Function evaluations: 7
#          Gradient evaluations: 7
#          Hessian evaluations: 0
# Iter  163  value:  -303.07367270319463
# Iter  164  value:  -303.07367270319673
# Warning: A bad approximation caused failure to predict improvement.
#          Current function value: -303.073673
#          Iterations: 0
#          Function evaluations: 2
#          Gradient evaluations: 1
#          Hessian evaluations: 0
# Done. Converged:  True
# This is nonzero if phi did anything: 1.0428162987440233
# Epsilon:  0.15
# Predicted differences:  2.103799198884645
# epsilon: 0.15
# Iter  165  value:  -301.8575893545684
# Iter  166  value:  -302.0213133318261
# Iter  167  value:  -302.040819172799
# Iter  168  value:  -302.0417222135421
# Iter  169  value:  -302.04209150309663
# Iter  170  value:  -302.04212685318515
# Iter  171  value:  -302.04212698564936
# Iter  172  value:  -302.04212698573593
# Optimization terminated successfully.
#          Current function value: -302.042127
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 8
#          Hessian evaluations: 0
# Iter  173  value:  -302.0421269857365
# Iter  174  value:  -302.0421269857358
# Warning: A bad approximation caused failure to predict improvement.
#          Current function value: -302.042127
#          Iterations: 0
#          Function evaluations: 2
#          Gradient evaluations: 1
#          Hessian evaluations: 0
# Done. Converged:  True
# This is nonzero if phi did anything: 1.406557286254422
# Epsilon:  0.2
# Predicted differences:  2.805065598512861
# epsilon: 0.2
# Iter  175  value:  -300.52216735307775
# Iter  176  value:  -301.00570386834187
# Iter  177  value:  -301.05913270069806
# Iter  178  value:  -301.06144515136714
# Iter  179  value:  -301.06181810522514
# Iter  180  value:  -301.06183808893934
# Iter  181  value:  -301.06183813426367
# Iter  182  value:  -301.06183813426594
# Optimization terminated successfully.
#          Current function value: -301.061838
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 8
#          Hessian evaluations: 0
# Iter  183  value:  -301.0618381342662
# Iter  184  value:  -301.06183813426514
# Warning: A bad approximation caused failure to predict improvement.
#          Current function value: -301.061838
#          Iterations: 0
#          Function evaluations: 2
#          Gradient evaluations: 1
#          Hessian evaluations: 0
# Done. Converged:  True
# This is nonzero if phi did anything: 1.7110019306262738
# Epsilon:  0.3
# Predicted differences:  4.207598397769291
# epsilon: 0.3
# Iter  185  value:  -296.896123178892
# Iter  186  value:  -298.4284746951113
# Iter  187  value:  -299.14411112212815
# Iter  188  value:  -299.2089802413101
# Iter  189  value:  -299.21731521321954
# Iter  190  value:  -299.2186471760459
# Iter  191  value:  -299.21870389718646
# Iter  192  value:  -299.2187042571627
# Iter  193  value:  -299.218704257364
# Optimization terminated successfully.
#          Current function value: -299.218704
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
#          Hessian evaluations: 0
# Iter  194  value:  -299.2187042573649
# Iter  195  value:  -299.2187042573631
# Warning: A bad approximation caused failure to predict improvement.
#          Current function value: -299.218704
#          Iterations: 0
#          Function evaluations: 2
#          Gradient evaluations: 1
#          Hessian evaluations: 0
# Done. Converged:  True
# This is nonzero if phi did anything: 2.2053805838174596
# Epsilon:  0.4
# Predicted differences:  5.610131197025722
# epsilon: 0.4
# Iter  196  value:  -291.28742595308466
# Iter  197  value:  -294.1790582314184
# Iter  198  value:  -295.8369073463056
# Iter  199  value:  -296.837529700122
# Iter  200  value:  -297.33192121414277
# Iter  201  value:  -297.45452641098495
# Iter  202  value:  -297.4870470758719
# Iter  203  value:  -297.4930576286928
# Iter  204  value:  -297.49426491614173
# Iter  205  value:  -297.4942989805274
# Iter  206  value:  -297.4942990352188
# Iter  207  value:  -297.4942990352333
# Optimization terminated successfully.
#          Current function value: -297.494299
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
#          Hessian evaluations: 0
# Iter  208  value:  -297.4942990352324
# Iter  209  value:  -297.4942990352331
# Warning: A bad approximation caused failure to predict improvement.
#          Current function value: -297.494299
#          Iterations: 0
#          Function evaluations: 2
#          Gradient evaluations: 1
#          Hessian evaluations: 0
# Done. Converged:  True
# This is nonzero if phi did anything: 2.6045593346103293
# Epsilon:  0.6
# Predicted differences:  8.415196795538582
# epsilon: 0.6
# Iter  210  value:  -271.60316496655804
# Iter  211  value:  -277.6597094433469
# Iter  212  value:  -282.08194321930415
# Iter  213  value:  -285.95748322406325
# Iter  214  value:  -287.4530782053535
# Iter  215  value:  -290.108953956955
# Iter  216  value:  -291.7573105067797
# Iter  217  value:  -292.86161821428277
# Iter  218  value:  -293.8816708394624
# Iter  219  value:  -294.1411714253021
# Iter  220  value:  -294.24846968292354
# Iter  221  value:  -294.2850730827384
# Iter  222  value:  -294.2951454503393
# Iter  223  value:  -294.2963220172807
# Iter  224  value:  -294.2963433711811
# Iter  225  value:  -294.29634344609394
# Iter  226  value:  -294.2963434461092
# Optimization terminated successfully.
#          Current function value: -294.296343
#          Iterations: 16
#          Function evaluations: 17
#          Gradient evaluations: 17
#          Hessian evaluations: 0
# Iter  227  value:  -294.29634344610923
# Iter  228  value:  -294.2963434461096
# Warning: A bad approximation caused failure to predict improvement.
#          Current function value: -294.296343
#          Iterations: 0
#          Function evaluations: 2
#          Gradient evaluations: 1
#          Hessian evaluations: 0
# Done. Converged:  True
# This is nonzero if phi did anything: 3.2386683685203477
# Epsilon:  0.8
# Predicted differences:  11.220262394051444
# epsilon: 0.8
# Iter  229  value:  -238.2124007576904
# Iter  230  value:  -250.90442043885423
# Iter  231  value:  -247.17006323773444
# Iter  232  value:  -256.5699675929263
# Iter  233  value:  -263.1625934984032
# Iter  234  value:  -271.4054754048533
# Iter  235  value:  -271.1875714699259
# Iter  236  value:  -274.3746435422399
# Iter  237  value:  -276.7675781642389
# Iter  238  value:  -279.0580686208664
# Iter  239  value:  -278.80879177623433
# Iter  240  value:  -280.49716140304145
# Iter  241  value:  -281.63459831739095
# Iter  242  value:  -284.2765595160434
# Iter  243  value:  -285.0128114940149
# Iter  244  value:  -287.71379001940295
# Iter  245  value:  -289.16622683786466
# Iter  246  value:  -292.6161750438102
# Iter  247  value:  -294.61902777063403
# Iter  248  value:  -296.96496862236756
# Iter  249  value:  -293.45299322712833
# Iter  250  value:  -299.8467059015187
# Iter  251  value:  -301.1989768768418
# Iter  252  value:  -303.22813063389145
# Iter  253  value:  -303.6463840255417
# Iter  254  value:  -279.272547133095
# Iter  255  value:  -304.04656750125883
# Iter  256  value:  -301.4377415428099
# Iter  257  value:  -304.3886995337916
# Iter  258  value:  -303.86255810155876
# Iter  259  value:  -304.56609552080727
# Iter  260  value:  -304.83706812795083
# Iter  261  value:  -304.9731568227108
# Iter  262  value:  -305.33837721609007
# Iter  263  value:  -305.7367714495256
# Iter  264  value:  -305.66562697634026
# Iter  265  value:  -305.9054248138728
# Iter  266  value:  -306.0310778050469
# Iter  267  value:  -306.1681651033655
# Iter  268  value:  -306.2072679908226
# Iter  269  value:  -306.2159217692959
# Iter  270  value:  -306.2183816499553
# Iter  271  value:  -306.21846862467527
# Iter  272  value:  -306.2184705852955
# Iter  273  value:  -306.21847058686706
# Optimization terminated successfully.
#          Current function value: -306.218471
#          Iterations: 44
#          Function evaluations: 45
#          Gradient evaluations: 37
#          Hessian evaluations: 0
# Iter  274  value:  -306.2184705868676
# Iter  275  value:  -306.2184705868665
# Optimization terminated successfully.
#          Current function value: -306.218471
#          Iterations: 1
#          Function evaluations: 2
#          Gradient evaluations: 1
#          Hessian evaluations: 0
# Done. Converged:  True
# This is nonzero if phi did anything: 6.4276118696723845
# Epsilon:  1.0
# Predicted differences:  14.025327992564304
# epsilon: 1.0
# Iter  276  value:  -188.6352362612406
# Iter  277  value:  -207.47847865009757
# Iter  278  value:  -204.25714145661723
# Iter  279  value:  -216.74283559209152
# Iter  280  value:  -230.6765727395149
# Iter  281  value:  -238.17300587717128
# Iter  282  value:  -229.07837787943433
# Iter  283  value:  -244.98476127649622
# Iter  284  value:  -250.22687355327
# Iter  285  value:  -257.42871469409636
# Iter  286  value:  -264.46581341478037
# Iter  287  value:  -268.242623084102
# Iter  288  value:  -276.83755758665086
# Iter  289  value:  -229.36731437346327
# Iter  290  value:  -272.2911756343348
# Iter  291  value:  -280.15548323949406
# Iter  292  value:  -282.25284145540707
# Iter  293  value:  -283.6272580243837
# Iter  294  value:  -285.51701621564877
# Iter  295  value:  -287.0272323806677
# Iter  296  value:  -288.3249899398423
# Iter  297  value:  -289.5793533936753
# Iter  298  value:  -290.3417225433845
# Iter  299  value:  -291.88294978076294
# Iter  300  value:  -293.086110152681
# Iter  301  value:  -293.1511324665594
# Iter  302  value:  -294.8865374574056
# Iter  303  value:  -296.40226330664416
# Iter  304  value:  -295.0519784452571
# Iter  305  value:  -297.1486564700837
# Iter  306  value:  -297.4800314871836
# Iter  307  value:  -295.7947898967523
# Iter  308  value:  -298.1708784248894
# Iter  309  value:  -298.41045689053686
# Iter  310  value:  -298.6870810264607
# Iter  311  value:  -299.12688870802845
# Iter  312  value:  -299.44134531383736
# Iter  313  value:  -299.89925065959045
# Iter  314  value:  -300.1594786577977
# Iter  315  value:  -300.2202785463294
# Iter  316  value:  -300.3305852012641
# Iter  317  value:  -300.5203824856223
# Iter  318  value:  -300.64757348683344
# Iter  319  value:  -300.7983141374317
# Iter  320  value:  -300.86667001320626
# Iter  321  value:  -300.94077639306187
# Iter  322  value:  -301.0662189839019
# Iter  323  value:  -301.13459668626984
# Iter  324  value:  -301.15104067433145
# Iter  325  value:  -301.15557770812825
# Iter  326  value:  -301.15728626208426
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: -301.157286
#          Iterations: 50
#          Function evaluations: 51
#          Gradient evaluations: 44
#          Hessian evaluations: 0
# Iter  327  value:  -301.15728626208323
# Iter  328  value:  -301.15808549001315
# Iter  329  value:  -300.7681399666081
# Iter  330  value:  -301.16855303133747
# Iter  331  value:  -301.19842002945717
# Iter  332  value:  -301.24261749967945
# Iter  333  value:  -301.3091718914161
# Iter  334  value:  -301.3177258974427
# Iter  335  value:  -301.31738026378247
# Iter  336  value:  -301.3498387722463
# Iter  337  value:  -301.39848283717157
# Iter  338  value:  -301.41674217452044
# Iter  339  value:  -301.4663896399457
# Iter  340  value:  -301.5387224309335
# Iter  341  value:  -301.5952581366701
# Iter  342  value:  -301.6423665758752
# Iter  343  value:  -301.676320881503
# Iter  344  value:  -301.691733127564
# Iter  345  value:  -301.6937597296924
# Iter  346  value:  -301.6938210770753
# Iter  347  value:  -301.6938240566526
# Iter  348  value:  -301.6938240570309
# Optimization terminated successfully.
#          Current function value: -301.693824
#          Iterations: 21
#          Function evaluations: 22
#          Gradient evaluations: 20
#          Hessian evaluations: 0
# Iter  349  value:  -301.69382405702993
# Iter  350  value:  -301.69382405703124
# Warning: A bad approximation caused failure to predict improvement.
#          Current function value: -301.693824
#          Iterations: 0
#          Function evaluations: 2
#          Gradient evaluations: 1
#          Hessian evaluations: 0
# Done. Converged:  True
# This is nonzero if phi did anything: 8.47334918935333

# %%
for i in range(len(epsilon_vec)): 
    plt.figure(figsize=(8, 4))
    plt.subplot(1, 2, 1)
    plt.plot(best_param_phi_array[i] - best_param_0, 
             best_param_phi_pred_array[i] - best_param_0, 'k.')
    plt.plot(best_param_phi_array[i] - best_param_0, 
             best_param_phi_array[i] - best_param_0, 'r')
    plt.xlabel('true diff global free params')
    plt.ylabel('pred diff global free params')
    plt.title('epsilon = {}'.format(epsilon_vec[i]))

    plt.subplot(1, 2, 2)
    plt.plot(output_phi_array[i] - output_0, 
             output_phi_pred_array[i] - output_0, 'k.')
    plt.plot(output_phi_array[i] - output_0, 
             output_phi_array[i] - output_0, 'r')
    plt.xlabel('true diff moment params')
    plt.ylabel('pred diff moment params')
    plt.title('epsilon = {}'.format(epsilon_vec[i]))
    
    plt.tight_layout()

# %%
plt.plot(epsilon_vec, output_phi_array, '+')
plt.plot(epsilon_vec, output_phi_pred_array, '+')

# %%
output_phi_pred_nonlin_array = []
for i in range(len(epsilon_vec)): 
    output_phi_pred_nonlin_array.append(
        epsilon_sensitivity.predict_output_par_from_hyperparameters(epsilon_vec[i], linear = False))

# %%
plt.plot(epsilon_vec, output_phi_array, '+')
plt.plot(epsilon_vec, output_phi_pred_nonlin_array, '+')
