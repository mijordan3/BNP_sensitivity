# %%
import numpy as np
from scipy.sparse.linalg import cg

# %%
dim = 100

_A = np.random.randn(dim, dim)
A = np.dot(_A.transpose(), _A)

b = np.random.randn(dim)

# %%
out = cg(A = A, b = b, callback = lambda x : print('foo'))
# Out:
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
# foo
